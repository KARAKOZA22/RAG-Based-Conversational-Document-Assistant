# %% [markdown]
# # Imports

# %%
# %%capture --no-display
# !pip install PyPDF2
# !pip install python-docx
# !pip install langchain-community sentence-transformers pinecone langchain_huggingface faiss-cpu groq scrapegraph_py dotenv

# %%
import pandas as pd
from dotenv import load_dotenv
import os
from groq import Groq
import re
import numpy as np
from sentence_transformers import SentenceTransformer
import faiss
from PyPDF2 import PdfReader
from docx import Document
import textwrap
from transformers import AutoModelForCausalLM, AutoTokenizer
from langchain_text_splitters import RecursiveCharacterTextSplitter
from transformers import pipeline
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS
from langchain_huggingface import HuggingFaceEmbeddings
from scrapegraph_py import Client
from scrapegraph_py.logger import sgai_logger

# %%
load_dotenv("/content/Agents.env")
# Out:
# True

# %% [markdown]
# # LLM

# %%
class ChatAssistant:
    def __init__(self, system_prompt="You are a helpful assistant", model="llama-3.3-70b-versatile"):
        self.client = Groq()
        self.model = model
        self.base_prompt = f"{system_prompt}"

    def invoke(self, user_input: str) -> str:
        response = self.client.chat.completions.create(
            model=self.model,
            messages=[{"role": "user", "content": user_input}],
            temperature=0,
            max_completion_tokens=1024,
        )
        return response.choices[0].message.content

# %% [markdown]
# # Retreival

# %%
class Retreival:
  def __init__(self):
        embedder = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
        index = faiss.IndexFlatL2(len(embedder.embed_query("hello world")))
        self.vector_store = FAISS(
            embedding_function=embedder,
            index=index,
            docstore=InMemoryDocstore(),
            index_to_docstore_id={},
        )

  def dict_to_string(self, data, indent=0):
      """Recursively convert a dictionary to a plain string."""
      result = ""
      if isinstance(data, dict):
          for key, value in data.items():
              result += " " * indent + f"{key}:\n"
              result += self.dict_to_string(value, indent + 4)
      elif isinstance(data, list):
          for item in data:
              result += self.dict_to_string(item, indent)
      else:
          result += " " * indent + f"{data}\n"
      return result

  def scrape_url(self, website_url):

      sgai_logger.set_logging(level="INFO")

      # Initialize the client
      sgai_client = Client(api_key=os.getenv('SCRAPE_API_KEY'))
      # SmartScraper request
      response = sgai_client.smartscraper(
          website_url=website_url,
          user_prompt="Extract webpage Content only forget about headlines just go to the content"
      )

      # Print the response
      result = self.dict_to_string(response['result'])

      sgai_client.close()

      return result

  def extract_text(self, file_path=None, url = None):

    if url!=None:
      return self.scrape_url(url)
    else:
      ext = os.path.splitext(file_path)[1].lower()
      if ext == '.txt':
          with open(file_path, 'r', encoding='utf-8') as file:
              return file.read()
      elif ext == '.pdf':
          reader = PdfReader(file_path)
          return ' '.join(page.extract_text() for page in reader.pages)
      elif ext == '.docx':
          doc = Document(file_path)
          return '\n'.join([para.text for para in doc.paragraphs])
      elif ext == '.csv':
          df = pd.read_csv(file_path)
          return df.to_string()
      else:
          raise ValueError(f"Unsupported file format: {ext}")


  def chunking (self, text, chunk_size=100, chunk_overlap = 20):

    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap,)


    texts = text_splitter.split_text(text)
    return texts

  def create_db(self, text):
    self.vector_store.add_texts(text)

  def retrieve_relevant_chunks(self, query, k=3):

    results = self.vector_store.similarity_search_with_relevance_scores(query, k=k)
    scores = [round(result[1],3) for result in results]
    results = [result[0].page_content for result in results]

    return results, scores

# %% [markdown]
# # Generation

# %%
class Generation:
    def __init__(self):

        self.generator = ChatAssistant()

    def format_input(self, query, retrieved_context):

        return f"Given this Context: {retrieved_context}\n You have to Answer this Query: {query}\nResponse:"

    def generate_response(self, query, retrieved_context):

        formatted_input = self.format_input(query, retrieved_context)
        response = self.generator.invoke(formatted_input)

        return response

# %% [markdown]
# # RAG

# %%
class RAG:
  def __init__(self, file_path=None, url=None):
    self.r1 = Retreival()
    self.g1 = Generation()
    self.text = self.r1.extract_text(file_path=file_path, url=url)
    self.chunks = self.r1.chunking(self.text, chunk_size=100, chunk_overlap = 20)
    self.r1.create_db(self.chunks)

  def generate(self, query, k):

    self.top_chunks = self.r1.retrieve_relevant_chunks(query, k=k)
    response = self.g1.generate_response(query, ''.join(self.top_chunks[0]))

    return response

  def print(self):
    print(self.text)
    print("*"*100)
    print(self.top_chunks)

# %% [markdown]
# # Test

# %%
rag_faiss = RAG(file_path = '/content/test.txt')
faiss_response = rag_faiss.generate("what is philosophy?", k = 3)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print(faiss_response)
# Out:
# Philosophy is a systematic study of general and fundamental questions concerning various topics, characterized by critical questioning and the development of principles, theories, and methods. It is an interdisciplinary field that is related to many other areas of study, including the sciences, and encompasses various branches and schools of thought that promote different approaches and perspectives.

# %%
rag_faiss.print()
# Out:
# Philosophy is a systematic study of general and fundamental questions concerning topics like existence, reason, knowledge, value, mind, and language. It is a rational and critical inquiry that reflects on its methods and assumptions.
#
# Historically, many of the individual sciences, such as physics and psychology, formed part of philosophy. However, they are considered separate academic disciplines in the modern sense of the term. Influential traditions in the history of philosophy include Western, Arabic–Persian, Indian, and Chinese philosophy. Western philosophy originated in Ancient Greece and covers a wide area of philosophical subfields. A central topic in Arabic–Persian philosophy is the relation between reason and revelation. Indian philosophy combines the spiritual problem of how to reach enlightenment with the exploration of the nature of reality and the ways of arriving at knowledge. Chinese philosophy focuses principally on practical issues about right social conduct, government, and self-cultivation.
#
# Major branches of philosophy are epistemology, ethics, logic, and metaphysics. Epistemology studies what knowledge is and how to acquire it. Ethics investigates moral principles and what constitutes right conduct. Logic is the study of correct reasoning and explores how good arguments can be distinguished from bad ones. Metaphysics examines the most general features of reality, existence, objects, and properties. Other subfields are aesthetics, philosophy of language, philosophy of mind, philosophy of religion, philosophy of science, philosophy of mathematics, philosophy of history, and political philosophy. Within each branch, there are competing schools of philosophy that promote different principles, theories, or methods.
#
# Philosophers use a great variety of methods to arrive at philosophical knowledge. They include conceptual analysis, reliance on common sense and intuitions, use of thought experiments, analysis of ordinary language, description of experience, and critical questioning. Philosophy is related to many other fields, including the sciences, mathematics, business, law, and journalism. It provides an interdisciplinary perspective and studies the scope and fundamental concepts of these fields. It also investigates their methods and ethical implications.
#
# Etymology
# The word philosophy comes from the Ancient Greek words φίλος (philos) 'love' and σοφία (sophia) 'wisdom'.[2][a] Some sources say that the term was coined by the pre-Socratic philosopher Pythagoras, but this is not certain.[4] The word entered the English language primarily from Old French and Anglo-Norman starting around 1175 CE. The French philosophie is itself a borrowing from the Latin philosophia. The term philosophy acquired the meanings of "advanced study of the speculative subjects (logic, ethics, physics, and metaphysics)", "deep wisdom consisting of love of truth and virtuous living", "profound learning as transmitted by the ancient writers", and "the study of the fundamental nature of knowledge, reality, and existence, and the basic limits of human understanding".[5]
#
# Before the modern age, the term philosophy was used in a wide sense. It included most forms of rational inquiry, such as the individual sciences, as its subdisciplines.[6] For instance, natural philosophy was a major branch of philosophy.[7] This branch of philosophy encompassed a wide range of fields, including disciplines like physics, chemistry, and biology.[8] An example of this usage is the 1687 book Philosophiæ Naturalis Principia Mathematica by Isaac Newton. This book referred to natural philosophy in its title, but it is today considered a book of physics.[9]
#
# The meaning of philosophy changed toward the end of the modern period when it acquired the more narrow meaning common today. In this new sense, the term is mainly associated with disciplines like metaphysics, epistemology, and ethics. Among other topics, it covers the rational study of reality, knowledge, and values. It is distinguished from other disciplines of rational inquiry such as the empirical sciences and mathematics.[10]
#
#
# ****************************************************************************************************
# (['Philosophy is a systematic study of general and fundamental questions concerning topics like', 'and critical questioning. Philosophy is related to many other fields, including the sciences,', 'of philosophy that promote different principles, theories, or methods.'], [np.float32(0.593), np.float32(0.551), np.float32(0.524)])

# %%
rag_faiss = RAG(url = 'https://en.wikipedia.org/wiki/Philosophy')
faiss_response = rag_faiss.generate("what is philosophy?", k = 3)
# Out:
# 💬 2025-03-22 20:32:33,168 🔑 Initializing Client
# INFO:scrapegraph:🔑 Initializing Client
# 💬 2025-03-22 20:32:33,170 ✅ Client initialized successfully
# INFO:scrapegraph:✅ Client initialized successfully
# 💬 2025-03-22 20:32:33,172 🔍 Starting smartscraper request
# INFO:scrapegraph:🔍 Starting smartscraper request
# 💬 2025-03-22 20:32:33,174 🚀 Making POST request to https://api.scrapegraphai.com/v1/smartscraper
# INFO:scrapegraph:🚀 Making POST request to https://api.scrapegraphai.com/v1/smartscraper
# 💬 2025-03-22 20:41:34,325 ✅ Request completed successfully: POST https://api.scrapegraphai.com/v1/smartscraper
# INFO:scrapegraph:✅ Request completed successfully: POST https://api.scrapegraphai.com/v1/smartscraper
# 💬 2025-03-22 20:41:34,330 ✨ Smartscraper request completed successfully
# INFO:scrapegraph:✨ Smartscraper request completed successfully
# 💬 2025-03-22 20:41:34,333 🔒 Closing Client session
# INFO:scrapegraph:🔒 Closing Client session

# %%
print(faiss_response)
# Out:
# Philosophy is the study of the nature and scope of knowledge, reality, and existence. It involves the examination of fundamental questions about the universe, human experience, and the nature of reality, including the methods and goals of intellectual inquiry. Philosophy encompasses various branches, such as metaphysics, epistemology, ethics, logic, and aesthetics, and seeks to provide a deeper understanding of the world and our place within it.

# %%
rag_faiss.print()
# Out:
# branches:
#     name:
#         Applied Philosophy
#     description:
#         The application of philosophical principles to real-world problems and issues.
#     name:
#         Logic
#     description:
#         The study of reasoning and argumentation, including the principles of inference and the structure of arguments.
#     name:
#         Metaphilosophy
#     description:
#         The study of the nature and scope of philosophy, including the methods and goals of philosophical inquiry.
#     name:
#         Philosophy of Education
#     description:
#         The study of the nature and goals of education, including the role of philosophy in educational theory and practice.
#     name:
#         Philosophy of Information
#     description:
#         The study of the nature and role of information in society, including the ethics of information and communication.
#     name:
#         Philosophy of Language
#     description:
#         The study of the nature and role of language in society, including the philosophy of meaning and reference.
#     name:
#         Philosophy of Mathematics
#     description:
#         The study of the nature and role of mathematics in society, including the philosophy of mathematical truth and reality.
#     name:
#         Philosophy of Religion
#     description:
#         The study of the nature and role of religion in society, including the philosophy of religious belief and practice.
#     name:
#         Philosophy of Science
#     description:
#         The study of the nature and role of science in society, including the philosophy of scientific method and theory.
#     name:
#         Political Philosophy
#     description:
#         The study of the nature and role of politics in society, including the philosophy of justice and morality.
#     name:
#         Practical Philosophy
#     description:
#         The study of the application of philosophical principles to practical problems and issues.
#     name:
#         Social Philosophy
#     description:
#         The study of the nature and role of social relationships and institutions in society, including the philosophy of social justice and morality.
#     name:
#         Theoretical Philosophy
#     description:
#         The study of the fundamental principles and concepts of philosophy, including the nature of reality and knowledge.
# subfields:
#     name:
#         Rationalism
#     description:
#         The view that reason is the primary source of knowledge and understanding.
#     name:
#         Skepticism
#     description:
#         The view that knowledge is uncertain or impossible to attain.
#     name:
#         Solipsism
#     description:
#         The view that only one's own mind is sure to exist.
#     name:
#         Ethics
#     description:
#         The study of moral principles and values.
#     name:
#         Consequentialism
#     description:
#         The view that the morality of an action is determined by its consequences.
#     name:
#         Deontology
#     description:
#         The view that the morality of an action is determined by its adherence to moral rules and duties.
#     name:
#         Virtue
#     description:
#         The study of moral character and the development of virtues.
#     name:
#         Free will
#     description:
#         The study of the nature of free will and its relationship to moral responsibility.
#     name:
#         Compatibilism
#     description:
#         The view that free will and determinism are compatible.
#     name:
#         Determinism
#     description:
#         The view that the course of events is predetermined and that free will is an illusion.
#     name:
#         Hard determinism
#     description:
#         The view that determinism is absolute and that free will is impossible.
#     name:
#         Incompatibilism
#     description:
#         The view that free will and determinism are incompatible.
#     name:
#         Hard incompatibilism
#     description:
#         The view that free will is impossible and that determinism is absolute.
#     name:
#         Libertarianism
#     description:
#         The view that free will is real and that individuals have the power to make choices.
#     name:
#         Metaphysics
#     description:
#         The study of the fundamental nature of reality and existence.
#     name:
#         Atomism
#     description:
#         The view that reality is composed of indivisible particles or atoms.
#     name:
#         Dualism
#     description:
#         The view that reality consists of two fundamental substances or principles.
#     name:
#         Idealism
#     description:
#         The view that reality is fundamentally mental or spiritual.
#     name:
#         Monism
#     description:
#         The view that reality is fundamentally one and indivisible.
#     name:
#         Naturalism
#     description:
#         The view that reality is fundamentally natural and governed by natural laws.
#     name:
#         Realism
#     description:
#         The view that reality is independent of human perception and understanding.
#     name:
#         Mind
#     description:
#         The study of the nature of the mind and its relationship to the body and the world.
#     name:
#         Behaviorism
#     description:
#         The view that the mind can be understood in terms of observable behavior.
#     name:
#         Eliminativism
#     description:
#         The view that the mind is an illusion and that mental states do not exist.
#     name:
#         Emergentism
#     description:
#         The view that the mind arises from the interactions of individual components.
#     name:
#         Epiphenomenalism
#     description:
#         The view that the mind is a byproduct of physical processes and has no causal power.
#     name:
#         Functionalism
#     description:
#         The view that the mind can be understood in terms of its functional properties and roles.
#     name:
#         Objectivism
#     description:
#         The view that knowledge and reality are independent of human perception and understanding.
#     name:
#         Subjectivism
#     description:
#         The view that knowledge and reality are relative to individual perspectives and experiences.
#     name:
#         Normativity
#     description:
#         The study of moral and epistemic norms and standards.
#     name:
#         Absolutism
#     description:
#         The view that moral and epistemic norms are absolute and universal.
#     name:
#         Particularism
#     description:
#         The view that moral and epistemic norms are relative to individual circumstances and contexts.
#     name:
#         Relativism
#     description:
#         The view that knowledge and reality are relative to individual perspectives and experiences.
#     name:
#         Nihilism
#     description:
#         The view that life has no inherent meaning or value.
#     name:
#         Skepticism
#     description:
#         The view that knowledge is uncertain or impossible to attain.
#     name:
#         Universalism
#     description:
#         The view that moral and epistemic norms are universal and apply to all individuals.
#     name:
#         Ontology
#     description:
#         The study of the nature of existence and reality.
#     name:
#         Action
#     description:
#         The study of the nature of action and agency.
#     name:
#         Event
#     description:
#         The study of the nature of events and their relationship to reality.
#     name:
#         Process
#     description:
#         The study of the nature of processes and their relationship to reality.
#     name:
#         Reality
#     description:
#         The study of the nature of reality and existence.
#     name:
#         Anti-realism
#     description:
#         The view that reality is not independent of human perception and understanding.
#     name:
#         Conceptualism
#     description:
#         The view that reality is fundamentally conceptual and mental.
#     name:
#         Idealism
#     description:
#         The view that reality is fundamentally mental or spiritual.
#     name:
#         Materialism
#     description:
#         The view that reality is fundamentally physical and material.
#     name:
#         Naturalism
#     description:
#         The view that reality is fundamentally natural and governed by natural laws.
#     name:
#         Nominalism
#     description:
#         The view that abstract entities and concepts are mere names or labels.
#     name:
#         Physicalism
#     description:
#         The view that reality is fundamentally physical and material.
#     name:
#         Realism
#     description:
#         The view that reality is independent of human perception and understanding.
# eras:
#     name:
#         Ancient
#     description:
#         The period of ancient philosophy, including the Presocratics, Socrates, Plato, and Aristotle.
#     name:
#         Western
#     description:
#         The period of Western philosophy, including the Middle Ages, the Renaissance, and the Enlightenment.
#     name:
#         Medieval
#     description:
#         The period of medieval philosophy, including the Scholastics and the rise of universities.
#     name:
#         Renaissance
#     description:
#         The period of Renaissance philosophy, including the revival of classical learning and the emergence of modern science.
#     name:
#         Early modern
#     description:
#         The period of early modern philosophy, including the Enlightenment and the rise of modern science.
#     name:
#         Modern
#     description:
#         The period of modern philosophy, including the 19th and 20th centuries and the rise of analytic philosophy.
#     name:
#         Contemporary
#     description:
#         The period of contemporary philosophy, including the 21st century and the rise of global philosophy.
# regions:
#     name:
#         African
#     description:
#         The study of philosophy in Africa, including the history and development of African philosophy.
#     name:
#         Bantu
#     description:
#         The study of philosophy in Bantu cultures, including the history and development of Bantu philosophy.
#     name:
#         Egyptian
#     description:
#         The study of philosophy in ancient Egypt, including the history and development of Egyptian philosophy.
#     name:
#         Ethiopian
#     description:
#         The study of philosophy in Ethiopia, including the history and development of Ethiopian philosophy.
#     name:
#         Africana
#     description:
#         The study of philosophy in Africa and the African diaspora, including the history and development of Africana philosophy.
#     name:
#         Eastern
#     description:
#         The study of philosophy in Eastern cultures, including the history and development of Eastern philosophy.
#     name:
#         Buddhist
#     description:
#         The study of philosophy in Buddhism, including the history and development of Buddhist philosophy.
#     name:
#         Chinese
#     description:
#         The study of philosophy in China, including the history and development of Chinese philosophy.
#     name:
#         Indian
#     description:
#         The study of philosophy in India, including the history and development of Indian philosophy.
#     name:
#         Indonesian
#     description:
#         The study of philosophy in Indonesia, including the history and development of Indonesian philosophy.
#     name:
#         Japanese
#     description:
#         The study of philosophy in Japan, including the history and development of Japanese philosophy.
#     name:
#         Korean
#     description:
#         The study of philosophy in Korea, including the history and development of Korean philosophy.
#     name:
#         Taiwanese
#     description:
#         The study of philosophy in Taiwan, including the history and development of Taiwanese philosophy.
#     name:
#         Vietnamese
#     description:
#         The study of philosophy in Vietnam, including the history and development of Vietnamese philosophy.
#     name:
#         Middle Eastern
#     description:
#         The study of philosophy in the Middle East, including the history and development of Middle Eastern philosophy.
#     name:
#         Iranian
#     description:
#         The study of philosophy in Iran, including the history and development of Iranian philosophy.
#     name:
#         Islamic
#     description:
#         The study of philosophy in Islam, including the history and development of Islamic philosophy.
#     name:
#         Jewish
#     description:
#         The study of philosophy in Judaism, including the history and development of Jewish philosophy.
#     name:
#         Pakistani
#     description:
#         The study of philosophy in Pakistan, including the history and development of Pakistani philosophy.
#     name:
#         Turkish
#     description:
#         The study of philosophy in Turkey, including the history and development of Turkish philosophy.
#     name:
#         Western
#     description:
#         The study of philosophy in the Western world, including the history and development of Western philosophy.
#     name:
#         American
#     description:
#         The study of philosophy in the United States, including the history and development of American philosophy.
#     name:
#         Australian
#     description:
#         The study of philosophy in Australia, including the history and development of Australian philosophy.
#     name:
#         British
#     description:
#         The study of philosophy in the United Kingdom, including the history and development of British philosophy.
#     name:
#         Scottish
#     description:
#         The study of philosophy in Scotland, including the history and development of Scottish philosophy.
#     name:
#         Canadian
#     description:
#         The study of philosophy in Canada, including the history and development of Canadian philosophy.
#     name:
#         Czech
#     description:
#         The study of philosophy in the Czech Republic, including the history and development of Czech philosophy.
#     name:
#         Danish
#     description:
#         The study of philosophy in Denmark, including the history and development of Danish philosophy.
#     name:
#         Dutch
#     description:
#         The study of philosophy in the Netherlands, including the history and development of Dutch philosophy.
#     name:
#         Finnish
#     description:
#         The study of philosophy in Finland, including the history and development of Finnish philosophy.
#     name:
#         French
#     description:
#         The study of philosophy in France, including the history and development of French philosophy.
#     name:
#         German
#     description:
#         The study of philosophy in Germany, including the history and development of German philosophy.
#     name:
#         Greek
#     description:
#         The study of philosophy in Greece, including the history and development of Greek philosophy.
#     name:
#         Italian
#     description:
#         The study of philosophy in Italy, including the history and development of Italian philosophy.
#     name:
#         Maltese
#     description:
#         The study of philosophy in Malta, including the history and development of Maltese philosophy.
#     name:
#         Polish
#     description:
#         The study of philosophy in Poland, including the history and development of Polish philosophy.
#     name:
#         Slovene
#     description:
#         The study of philosophy in Slovenia, including the history and development of Slovene philosophy.
#     name:
#         Spanish
#     description:
#         The study of philosophy in Spain, including the history and development of Spanish philosophy.
# disciplines:
#     name:
#         Anthropology
#     description:
#         The study of human cultures, behaviors, and societies.
#     name:
#         Archaeology
#     description:
#         The study of past human cultures through the excavation and analysis of material remains.
#     name:
#         Classical studies
#     description:
#         The study of ancient Greek and Roman cultures, languages, and histories.
#     name:
#         History
#     description:
#         The study of past events, people, and cultures.
#     name:
#         Language arts
#     description:
#         The study of language, literature, and communication.
#     name:
#         Literature
#     description:
#         The study of written works, including poetry, fiction, and drama.
#     name:
#         Poetry
#     description:
#         The study of poetry, including its forms, themes, and techniques.
#     name:
#         Rhetoric
#     description:
#         The study of persuasive communication, including speech and writing.
#     name:
#         Law
#     description:
#         The study of the principles and rules that govern human behavior and relationships.
#     name:
#         Performing arts
#     description:
#         The study of music, dance, theater, and other forms of performance.
#     name:
#         Dance
#     description:
#         The study of dance, including its history, techniques, and cultural significance.
#     name:
#         Music
#     description:
#         The study of music, including its history, theory, and performance.
#     name:
#         Theatre
#     description:
#         The study of theater, including its history, theory, and performance.
#     name:
#         Philosophy
#     description:
#         The study of fundamental questions about existence, knowledge, values, reason, mind, and language.
#     name:
#         Religious studies
#     description:
#         The study of religion, including its history, theory, and practice.
#     name:
#         Visual arts
#     description:
#         The study of visual arts, including painting, sculpture, and other forms of visual expression.
#     name:
#         Filmmaking
#     description:
#         The study of filmmaking, including its history, theory, and practice.
#     name:
#         Painting
#     description:
#         The study of painting, including its history, techniques, and cultural significance.
#     name:
#         Sculpture
#     description:
#         The study of sculpture, including its history, techniques, and cultural significance.
# interdisciplinary fields:
#     name:
#         Digital humanities
#     description:
#         The study of the intersection of digital technology and the humanities.
#     name:
#         Environmental humanities
#     description:
#         The study of the relationship between humans and the natural environment.
#     name:
#         Health humanities
#     description:
#         The study of the intersection of health and the humanities.
#     name:
#         Medical humanities
#     description:
#         The study of the intersection of medicine and the humanities.
#     name:
#         Public humanities
#     description:
#         The study of the intersection of the humanities and public policy.
# themes:
#     name:
#         Abductive reasoning
#     description:
#         The process of making educated guesses or hypotheses based on incomplete information.
#     name:
#         Aesthetics
#     description:
#         The study of beauty, taste, and art.
#     name:
#         Antipositivism
#     description:
#         The view that knowledge cannot be reduced to empirical facts and data.
#     name:
#         The arts
#     description:
#         The study of creative expression, including music, dance, theater, and visual arts.
#     name:
#         Beauty
#     description:
#         The study of beauty, including its nature, causes, and effects.
#     name:
#         Belles-lettres
#     description:
#         The study of literature and the arts.
#     name:
#         Bildung
#     description:
#         The study of personal development and education.
#     name:
#         Creativity
#     description:
#         The study of creative expression and innovation.
#     name:
#         Critical theory
#     description:
#         The study of the relationship between power and knowledge.
#     name:
#         Criticism
#     description:
#         The study of the evaluation and interpretation of artistic and literary works.
#     name:
#         Cultural literacy
#     description:
#         The study of the knowledge and skills necessary to participate in a culture.
#     name:
#         Culture
#     description:
#         The study of human cultures, including their history, customs, and values.
#     name:
#         High culture
#     description:
#         The study of high art and literature.
#     name:
#         Pop culture
#     description:
#         The study of popular culture, including music, film, and television.
#     name:
#         General knowledge
#     description:
#         The study of general knowledge and education.
#     name:
#         Hermeneutics
#     description:
#         The study of interpretation and understanding.
#     name:
#         Historicism
#     description:
#         The study of the relationship between history and culture.
#     name:
#         Historism
#     description:
#         The study of the relationship between history and culture.
#     name:
#         Human condition
#     description:
#         The study of the human experience and condition.
#     name:
#         Humanitas
#     description:
#         The study of human culture and civilization.
#     name:
#         Liberal arts education
#     description:
#         The study of the liberal arts, including language, literature, and philosophy.
#     name:
#         Trivium
#     description:
#         The study of the three liberal arts: grammar, logic, and rhetoric.
#     name:
#         Quadrivium
#     description:
#         The study of the four liberal arts: arithmetic, geometry, astronomy, and music.
#     name:
#         Metaphysics
#     description:
#         The study of the fundamental nature of reality and existence.
#     name:
#         Ontology
#     description:
#         The study of the nature of existence and reality.
#     name:
#         Moral character
#     description:
#         The study of moral character and development.
#     name:
#         Self-realization
#     description:
#         The study of personal growth and self-awareness.
#     name:
#         Self-reflection
#     description:
#         The study of introspection and self-awareness.
#     name:
#         Wisdom
#     description:
#         The study of wisdom and its relationship to knowledge and experience.
#     name:
#         Work of art
#     description:
#         The study of the nature and meaning of art.
# journals:
#     name:
#         American Journal of Archaeology
#     description:
#         A journal of archaeology and ancient history.
#     name:
#         Daedalus
#     description:
#         A journal of the American Academy of Arts and Sciences.
#     name:
#         History of Humanities
#     description:
#         A journal of the history of the humanities.
#     name:
#         Humanitas
#     description:
#         A journal of the humanities and social sciences.
#     name:
#         Humanities and Social Sciences Communications
#     description:
#         A journal of the humanities and social sciences.
#     name:
#         Journal of Controversial Ideas
#     description:
#         A journal of controversial ideas and debates.
#     name:
#         Journal of the Royal Asiatic Society
#     description:
#         A journal of Asian studies and culture.
#     name:
#         Leonardo
#     description:
#         A journal of art, science, and technology.
#     name:
#         Nova Religio
#     description:
#         A journal of new religious movements and spirituality.
#     name:
#         Revue des Études Arméniennes
#     description:
#         A journal of Armenian studies and culture.
#     name:
#         Teaching Philosophy
#     description:
#         A journal of teaching philosophy and pedagogy.
# academia:
#     name:
#         Arts and Humanities Research Council
#     description:
#         A research council for the arts and humanities in the UK.
#     name:
#         Human science
#     description:
#         The study of human culture and behavior.
#     name:
#         Humanities, arts, and social sciences
#     description:
#         The study of the humanities, arts, and social sciences.
#     name:
#         Master of Humanities
#     description:
#         A graduate degree in the humanities.
#     name:
#         Moscow University for the Humanities
#     description:
#         A university for the humanities in Moscow.
#     name:
#         National Endowment for the Humanities
#     description:
#         A research council for the humanities in the US.
#     name:
#         National Humanities Medal
#     description:
#         A medal for outstanding contributions to the humanities.
# related:
#     name:
#         Antihumanism
#     description:
#         The view that human culture and values are inferior to those of other species.
#     name:
#         Criticism of mass culture
#     description:
#         The study of the negative effects of mass culture on society.
#     name:
#         Educational essentialism
#     description:
#         The view that education should focus on the transmission of essential knowledge and skills.
#     name:
#         Humanities in the United States
#     description:
#         The study of the humanities in the US, including their history and development.
#     name:
#         List of people considered a founder in a humanities field
#     description:
#         A list of people who have made significant contributions to a humanities field.
#     name:
#         Outline of the humanities
#     description:
#         A comprehensive outline of the humanities, including their history and development.
#     name:
#         Renaissance humanism
#     description:
#         The study of the revival of classical learning and culture in the Renaissance.
#     name:
#         Studia Humanitatis
#     description:
#         The study of the humanities, including their history and development.
#
# ****************************************************************************************************
# (['The study of the nature and scope of philosophy, including the methods and goals of', 'The study of philosophy in the United States, including the history and development of', 'name:\n        Philosophy\n    description:'], [np.float32(0.54), np.float32(0.534), np.float32(0.526)])
